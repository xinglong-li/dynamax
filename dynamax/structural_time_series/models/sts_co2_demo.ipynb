# %%
import os
os.chdir('/home/xinglong/git_local/dynamax/')
import jax
jax.config.update('jax_platform_name', 'cpu')
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import jax.numpy as jnp
import jax.random as jr
from jax.tree_util import tree_map
import optax

import dynamax.structural_time_series.models.sts_model as sts
# CO2 readings from Mauna Loa observatory, monthly beginning January 1966
# Original source: http://scrippsco2.ucsd.edu/data/atmospheric_co2/primary_mlo_co2_record
co2_by_month = np.array(
    "320.62,321.60,322.39,323.70,324.08,323.75,322.38,320.36,318.64,318.10,319.78,321.03,322.33,322.50,323.04,324.42,325.00,324.09,322.54,320.92,319.25,319.39,320.73,321.96,322.57,323.15,323.89,325.02,325.57,325.36,324.14,322.11,320.33,320.25,321.32,322.89,324.00,324.42,325.63,326.66,327.38,326.71,325.88,323.66,322.38,321.78,322.85,324.12,325.06,325.98,326.93,328.14,328.08,327.67,326.34,324.69,323.10,323.06,324.01,325.13,326.17,326.68,327.17,327.79,328.92,328.57,327.36,325.43,323.36,323.56,324.80,326.01,326.77,327.63,327.75,329.73,330.07,329.09,328.04,326.32,324.84,325.20,326.50,327.55,328.55,329.56,330.30,331.50,332.48,332.07,330.87,329.31,327.51,327.18,328.16,328.64,329.35,330.71,331.48,332.65,333.09,332.25,331.18,329.39,327.43,327.37,328.46,329.57,330.40,331.40,332.04,333.31,333.97,333.60,331.90,330.06,328.56,328.34,329.49,330.76,331.75,332.56,333.50,334.58,334.88,334.33,333.05,330.94,329.30,328.94,330.31,331.68,332.93,333.42,334.70,336.07,336.75,336.27,334.92,332.75,331.59,331.16,332.40,333.85,334.97,335.38,336.64,337.76,338.01,337.89,336.54,334.68,332.76,332.55,333.92,334.95,336.23,336.76,337.96,338.88,339.47,339.29,337.73,336.09,333.92,333.86,335.29,336.73,338.01,338.36,340.07,340.77,341.47,341.17,339.56,337.60,335.88,336.02,337.10,338.21,339.24,340.48,341.38,342.51,342.91,342.25,340.49,338.43,336.69,336.86,338.36,339.61,340.75,341.61,342.70,343.57,344.14,343.35,342.06,339.81,337.98,337.86,339.26,340.49,341.38,342.52,343.10,344.94,345.76,345.32,343.98,342.38,339.87,339.99,341.15,342.99,343.70,344.50,345.28,347.06,347.43,346.80,345.39,343.28,341.07,341.35,342.98,344.22,344.97,345.99,347.42,348.35,348.93,348.25,346.56,344.67,343.09,342.80,344.24,345.56,346.30,346.95,347.85,349.55,350.21,349.55,347.94,345.90,344.85,344.17,345.66,346.90,348.02,348.48,349.42,350.99,351.85,351.26,349.51,348.10,346.45,346.36,347.81,348.96,350.43,351.73,352.22,353.59,354.22,353.79,352.38,350.43,348.73,348.88,350.07,351.34,352.76,353.07,353.68,355.42,355.67,355.12,353.90,351.67,349.80,349.99,351.30,352.52,353.66,354.70,355.38,356.20,357.16,356.23,354.81,352.91,350.96,351.18,352.83,354.21,354.72,355.75,357.16,358.60,359.34,358.24,356.17,354.02,352.15,352.21,353.75,354.99,355.99,356.72,357.81,359.15,359.66,359.25,357.02,355.00,353.01,353.31,354.16,355.40,356.70,357.17,358.38,359.46,360.28,359.60,357.57,355.52,353.69,353.99,355.34,356.80,358.37,358.91,359.97,361.26,361.69,360.94,359.55,357.48,355.84,356.00,357.58,359.04,359.97,361.00,361.64,363.45,363.80,363.26,361.89,359.45,358.05,357.75,359.56,360.70,362.05,363.24,364.02,364.71,365.41,364.97,363.65,361.48,359.45,359.61,360.76,362.33,363.18,363.99,364.56,366.36,366.80,365.63,364.47,362.50,360.19,360.78,362.43,364.28,365.33,366.15,367.31,368.61,369.30,368.88,367.64,365.78,363.90,364.23,365.46,366.97,368.15,368.87,369.59,371.14,371.00,370.35,369.27,366.93,364.64,365.13,366.68,368.00,369.14,369.46,370.51,371.66,371.83,371.69,370.12,368.12,366.62,366.73,368.29,369.53,370.28,371.50,372.12,372.86,374.02,373.31,371.62,369.55,367.96,368.09,369.68,371.24,372.44,373.08,373.52,374.85,375.55,375.40,374.02,371.48,370.70,370.25,372.08,373.78,374.68,375.62,376.11,377.65,378.35,378.13,376.61,374.48,372.98,373.00,374.35,375.69,376.79,377.36,378.39,380.50,380.62,379.55,377.76,375.83,374.05,374.22,375.84,377.44,378.34,379.61,380.08,382.05,382.24,382.08,380.67,378.67,376.42,376.80,378.31,379.96,381.37,382.02,382.56,384.37,384.92,384.03,382.28,380.48,378.81,379.06,380.14,381.66,382.58,383.71,384.34,386.23,386.41,385.87,384.45,381.84,380.86,380.86,382.36,383.61,385.07,385.84,385.83,386.77,388.51,388.05,386.25,384.08,383.09,382.78,384.01,385.11,386.65,387.12,388.52,389.57,390.16,389.62,388.07,386.08,384.65,384.33,386.05,387.49,388.55,390.07,391.01,392.38,393.22,392.24,390.33,388.52,386.84,387.16,388.67,389.81,391.30,391.92,392.45,393.37,394.28,393.69,392.59,390.21,389.00,388.93,390.24,391.80,393.07,393.35,394.36,396.43,396.87,395.88,394.52,392.54,391.13,391.01,392.95,394.34,395.61,396.85,397.26,398.35,399.98,398.87,397.37,395.41,393.39,393.70,395.19,396.82,397.92,398.10,399.47,401.33,401.88,401.31,399.07,397.21,395.40,395.65,397.23,398.79,399.85,400.31,401.51,403.45,404.10,402.88,401.61,399.00,397.50,398.28,400.24,401.89,402.65,404.16,404.85,407.57,407.66,407.00,404.50,402.24,401.01,401.50,403.64,404.55,406.07,406.64,407.06,408.95,409.91,409.12,407.20,405.24,403.27,403.64,405.17,406.75,408.05,408.34,409.25,410.30,411.30,410.88,408.90,407.10,405.59,405.99,408.12,409.23,410.92".split(",")
).astype(np.float32)
co2_by_month = jnp.array(co2_by_month[:, None])

num_forecast_steps = 12 * 10  # Forecast the final ten years, given previous data
co2_by_month_training_data = co2_by_month[:-num_forecast_steps]

# Plot the original data
co2_dates = np.arange("1966-01", "2019-02", dtype="datetime64[M]")
co2_loc = mdates.YearLocator(7)
co2_fmt = mdates.DateFormatter("%Y")
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(1, 1, 1)
ax.plot(co2_dates[:-num_forecast_steps], co2_by_month_training_data, lw=2, label='training data', markersize=1)
ax.grid()
ax.xaxis.set_major_locator(co2_loc)
ax.xaxis.set_major_formatter(co2_fmt)
ax.set_ylabel("Atmospheric CO2 concentration (ppm)")
ax.set_xlabel("Year")

fig.suptitle("Monthly average CO2 concentration Mauna Loa, Hawaii", fontsize=15)
ax.text(
    0.99,
    0.02,
    "Source: Scripps Institute for Oceanography CO2 program\nhttp://scrippsco2.ucsd.edu/data/atmospheric_co2/primary_mlo_co2_record",
    transform=ax.transAxes,
    horizontalalignment='right',
    alpha=0.5
)
fig.autofmt_xdate()
def plot_forecast(model, parameter_samples, observed_time_series):
    # Forecast
    forecasts = model.forecast(jr.PRNGKey(0), observed_time_series, parameter_samples, num_forecast_steps)
    forecast_means = jnp.squeeze(forecasts['means'].mean(axis=0))
    forecast_scales = jnp.squeeze(jnp.sqrt(forecasts['covariances']).mean(axis=0))

    # Plot the forecast
    fig = plt.figure(figsize=(12, 6))
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(co2_dates, co2_by_month, lw=2, label='Observation')
    ax.plot(co2_dates[-num_forecast_steps:], forecast_means, lw='2', color='orange', label='Forecast')
    ax.fill_between(co2_dates[-num_forecast_steps:], 
                    forecast_means - 2*forecast_scales, forecast_means + 2*forecast_scales,
                    color='orange', alpha=0.3)
    ax.set_ylabel("Atmospheric CO2 concentration (ppm)")
    ax.set_xlabel("Year")
    ax.legend()
    ax.grid()
    fig.suptitle("Monthly average CO2 concentration Mauna Loa, Hawaii", fontsize=15)

def plot_decompose(model, parameter_samples):
    # Decompose the fitted model into STS components
    component_posterior_dict = model.decompose_by_component(co2_by_month, sts_params=parameter_samples)

    # Plot the posterior of each component
    num_components = len(component_posterior_dict)
    fig = plt.figure(figsize=(12, 4 * num_components))
    for i, (component_name, component_posterior) in enumerate(component_posterior_dict.items()):
        component_mean = jnp.squeeze(component_posterior[0])
        component_std = jnp.squeeze(jnp.sqrt(component_posterior[1]))

        ax = fig.add_subplot(num_components, 1,1+i)
        ax.plot(co2_dates, component_mean, lw=2)
        ax.fill_between(co2_dates, component_mean-2.*component_std, component_mean+2.*component_std, alpha=0.5)
        ax.set_title(component_name)

# %% [markdown]
# ### Build STS models

# %%
# The model includes the local linear trend component and the seasonal component
trend = sts.LocalLinearTrend()
seasonal_dummy = sts.SeasonalDummy(num_seasons=12)
seasonal_trig = sts.SeasonalTrig(num_seasons=12)

# %%
# The model with the dummy seasonal component
model_dummy_season = sts.StructuralTimeSeries([trend, seasonal_dummy],
                                              obs_time_series=co2_by_month_training_data,
                                              obs_distribution_family='Gaussian')

# The model with the trigonometric seasonal component
model_trig_season = sts.StructuralTimeSeries([trend, seasonal_trig], 
                                             obs_time_series=co2_by_month_training_data,
                                             obs_distribution_family='Gaussian')

# %%
# Fit the model using HMC
obs_time_series = co2_by_month_training_data
key = jr.PRNGKey(0)
sample_size = 200

batch_obs = jnp.array([obs_time_series])

# %%
ssm = model_dummy_season.as_ssm()
ssm1 = model_trig_season.as_ssm()

# %%
ssm.marginal_log_prob(ssm.params, obs_time_series)
# Out:
# DeviceArray(-435.0507, dtype=float32)

# %% [markdown]
# ### Model Learning

# %%
# Fit the model using HMC
observed_time_series = co2_by_month_training_data
key = jr.PRNGKey(0)
sample_size = 200

# %% [markdown]
# ### Fitting with MLE

# %%
# Fit the model with dummy seasonal component
opt_param_dummy, _losses = model_dummy_season.fit_mle(observed_time_series, key=key)
param_dummy_sample = tree_map(lambda x: jnp.array([x]), opt_param_dummy)
# Out:
# /home/xinglong/.local/lib/python3.8/site-packages/jax/_src/tree_util.py:188: FutureWarning: jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() instead as a drop-in replacement.
#   warnings.warn('jax.tree_util.tree_multimap() is deprecated. Please use jax.tree_util.tree_map() '

# %%
ts = ssm.forecast(key, opt_param_dummy, observed_time_series, num_forecast_steps)

# %%
ssm.component_posterior(opt_param_dummy, obs_time_series)
# Out:
# OrderedDict([('local_linear_trend',
#               (DeviceArray([[320.7986 ],
#                             [320.92532],
#                             [321.04898],
#                             [321.1668 ],
#                             [321.2763 ],
#                             [321.37683],
#                             [321.46625],
#                             [321.54562],
#                             [321.61795],
#                             [321.6862 ],
#                             [321.7529 ],
#                             [321.81277],
#                             [321.86252],
#                             [321.90024],
#                             [321.93387],
#                             [321.97015],
#                             [322.01126],
#                             [322.0595 ],
#                             [322.12054],
#                             [322.19653],
#                             [322.28192],
#                             [322.37024],
#                             [322.4528 ],
#                             [322.52515],
#                             [322.5888 ],
#                             [322.65176],
#                             [322.72113],
#                             [322.80185],
#                             [322.896  ],
#                             [323.00162],
#                             [323.11273],
#                             [323.22656],
#                             [323.3442 ],
#                             [323.4681 ],
#                             [323.5991 ],
#                             [323.73816],
#                             [323.88174],
#                             [324.02765],
#                             [324.17688],
#                             [324.3248 ],
#                             [324.4699 ],
#                             [324.60797],
#                             [324.73605],
#                             [324.84814],
#                             [324.94513],
#                             [325.02658],
#                             [325.1005 ],
#                             [325.17322],
#                             [325.24768],
#                             [325.32465],
#                             [325.40164],
#                             [325.47632],
#                             [325.54984],
#                             [325.62827],
#                             [325.71008],
#                             [325.7913 ],
#                             [325.8639 ],
#                             [325.9217 ],
#                             [325.96222],
#                             [325.98907],
#                             [326.00754],
#                             [326.0236 ],
#                             [326.04745],
#                             [326.08917],
#                             [326.15585],
#                             [326.23926],
#                             [326.32962],
#                             [326.4195 ],
#                             [326.50534],
#                             [326.58752],
#                             [326.66254],
#                             [326.73   ],
#                             [326.79297],
#                             [326.85867],
#                             [326.93436],
#                             [327.03027],
#                             [327.14484],
#                             [327.28268],
#                             [327.4489 ],
#                             [327.6404 ],
#                             [327.8505 ],
#                             [328.06992],
#                             [328.2891 ],
#                             [328.50464],
#                             [328.7181 ],
#                             [328.93066],
#                             [329.14145],
#                             [329.34915],
#                             [329.54904],
#                             [329.73   ],
#                             [329.8816 ],
#                             [329.9951 ],
#                             [330.0645 ],
#                             [330.0931 ],
#                             [330.0922 ],
#                             [330.07797],
#                             [330.06973],
#                             [330.07758],
#                             [330.099  ],
#                             [330.1319 ],
#                             [330.1744 ],
#                             [330.22543],
#                             [330.28406],
#                             [330.3444 ],
#                             [330.40247],
#                             [330.4592 ],
#                             [330.51566],
#                             [330.57565],
#                             [330.64282],
#                             [330.72034],
#                             [330.80746],
#                             [330.90475],
#                             [331.00934],
#                             [331.11673],
#                             [331.22302],
#                             [331.32892],
#                             [331.43216],
#                             [331.52936],
#                             [331.62024],
#                             [331.70535],
#                             [331.78406],
#                             [331.8559 ],
#                             [331.9204 ],
#                             [331.9785 ],
#                             [332.03384],
#                             [332.09204],
#                             [332.1571 ],
#                             [332.23166],
#                             [332.32062],
#                             [332.4274 ],
#                             [332.5562 ],
#                             [332.70676],
#                             [332.87592],
#                             [333.05923],
#                             [333.25427],
#                             [333.4537 ],
#                             [333.65002],
#                             [333.83765],
#                             [334.01443],
#                             [334.17993],
#                             [334.3363 ],
#                             [334.48068],
#                             [334.6172 ],
#                             [334.7487 ],
#                             [334.875  ],
#                             [334.99734],
#                             [335.11926],
#                             [335.23996],
#                             [335.3597 ],
#                             [335.4795 ],
#                             [335.59424],
#                             [335.7006 ],
#                             [335.7981 ],
#                             [335.8904 ],
#                             [335.98178],
#                             [336.07516],
#                             [336.1744 ],
#                             [336.27954],
#                             [336.3923 ],
#                             [336.51233],
#                             [336.64102],
#                             [336.7768 ],
#                             [336.91568],
#                             [337.0572 ],
#                             [337.20087],
#                             [337.35223],
#                             [337.51315],
#                             [337.68182],
#                             [337.85388],
#                             [338.02475],
#                             [338.19394],
#                             [338.3546 ],
#                             [338.50842],
#                             [338.65402],
#                             [338.7899 ],
#                             [338.9179 ],
#                             [339.0398 ],
#                             [339.15567],
#                             [339.26535],
#                             [339.37204],
#                             [339.47742],
#                             [339.57892],
#                             [339.66925],
#                             [339.74747],
#                             [339.81613],
#                             [339.88187],
#                             [339.953  ],
#                             [340.03848],
#                             [340.14307],
#                             [340.26508],
#                             [340.3978 ],
#                             [340.53278],
#                             [340.66284],
#                             [340.7802 ],
#                             [340.8795 ],
#                             [340.95844],
#                             [341.0219 ],
#                             [341.07474],
#                             [341.12415],
#                             [341.17502],
#                             [341.23645],
#                             [341.315  ],
#                             [341.41638],
#                             [341.54358],
#                             [341.69867],
#                             [341.8813 ],
#                             [342.0854 ],
#                             [342.30652],
#                             [342.53107],
#                             [342.7468 ],
#                             [342.9451 ],
#                             [343.1211 ],
#                             [343.2743 ],
#                             [343.41516],
#                             [343.54913],
#                             [343.68054],
#                             [343.80676],
#                             [343.93024],
#                             [344.05185],
#                             [344.17136],
#                             [344.2838 ],
#                             [344.39053],
#                             [344.4941 ],
#                             [344.59784],
#                             [344.7082 ],
#                             [344.83148],
#                             [344.9653 ],
#                             [345.10492],
#                             [345.2479 ],
#                             [345.39212],
#                             [345.53043],
#                             [345.65408],
#                             [345.76425],
#                             [345.86264],
#                             [345.95267],
#                             [346.03845],
#                             [346.12155],
#                             [346.20227],
#                             [346.28455],
#                             [346.37097],
#                             [346.46463],
#                             [346.57065],
#                             [346.6914 ],
#                             [346.82434],
#                             [346.9618 ],
#                             [347.09848],
#                             [347.23215],
#                             [347.36203],
#                             [347.48734],
#                             [347.60333],
#                             [347.71747],
#                             [347.83453],
#                             [347.9598 ],
#                             [348.09784],
#                             [348.25504],
#                             [348.43216],
#                             [348.6256 ],
#                             [348.83057],
#                             [349.0449 ],
#                             [349.26797],
#                             [349.49344],
#                             [349.7189 ],
#                             [349.94525],
#                             [350.17303],
#                             [350.40204],
#                             [350.626  ],
#                             [350.83844],
#                             [351.04196],
#                             [351.23813],
#                             [351.42685],
#                             [351.60562],
#                             [351.77194],
#                             [351.92462],
#                             [352.0625 ],
#                             [352.18515],
#                             [352.29562],
#                             [352.39572],
#                             [352.48587],
#                             [352.57394],
#                             [352.66568],
#                             [352.7601 ],
#                             [352.86002],
#                             [352.96387],
#                             [353.06757],
#                             [353.17212],
#                             [353.27768],
#                             [353.38232],
#                             [353.4854 ],
#                             [353.58612],
#                             [353.68234],
#                             [353.7723 ],
#                             [353.8609 ],
#                             [353.95676],
#                             [354.06183],
#                             [354.18057],
#                             [354.31314],
#                             [354.4584 ],
#                             [354.61545],
#                             [354.77945],
#                             [354.94354],
#                             [355.1035 ],
#                             [355.25912],
#                             [355.40143],
#                             [355.51764],
#                             [355.60107],
#                             [355.65277],
#                             [355.68527],
#                             [355.71442],
#                             [355.7517 ],
#                             [355.80338],
#                             [355.87088],
#                             [355.9508 ],
#                             [356.03955],
#                             [356.13245],
#                             [356.22293],
#                             [356.30264],
#                             [356.36566],
#                             [356.41006],
#                             [356.43594],
#                             [356.45282],
#                             [356.46686],
#                             [356.48373],
#                             [356.5064 ],
#                             [356.54193],
#                             [356.59207],
#                             [356.6537 ],
#                             [356.7254 ],
#                             [356.8018 ],
#                             [356.88202],
#                             [356.9646 ],
#                             [357.0534 ],
#                             [357.15738],
#                             [357.28116],
#                             [357.42575],
#                             [357.58762],
#                             [357.76205],
#                             [357.94135],
#                             [358.11557],
#                             [358.28238],
#                             [358.44016],
#                             [358.59183],
#                             [358.74347],
#                             [358.901  ],
#                             [359.06668],
#                             [359.24155],
#                             [359.42383],
#                             [359.61105],
#                             [359.79935],
#                             [359.98584],
#                             [360.17014],
#                             [360.3493 ],
#                             [360.52338],
#                             [360.6884 ],
#                             [360.84647],
#                             [360.99933],
#                             [361.1495 ],
#                             [361.30273],
#                             [361.4588 ],
#                             [361.6211 ],
#                             [361.78534],
#                             [361.949  ],
#                             [362.10452],
#                             [362.24454],
#                             [362.36932],
#                             [362.48645],
#                             [362.5963 ],
#                             [362.69638],
#                             [362.78464],
#                             [362.8625 ],
#                             [362.934  ],
#                             [363.0021 ],
#                             [363.071  ],
#                             [363.14145],
#                             [363.21655],
#                             [363.29822],
#                             [363.38953],
#                             [363.48932],
#                             [363.60294],
#                             [363.74063],
#                             [363.90552],
#                             [364.10013],
#                             [364.32907],
#                             [364.58636],
#                             [364.86304],
#                             [365.14893],
#                             [365.43878],
#                             [365.72885],
#                             [366.01416],
#                             [366.29346],
#                             [366.56372],
#                             [366.8209 ],
#                             [367.06027],
#                             [367.27762],
#                             [367.47214],
#                             [367.64294],
#                             [367.79175],
#                             [367.91815],
#                             [368.02155],
#                             [368.1039 ],
#                             [368.16888],
#                             [368.22095],
#                             [368.27142],
#                             [368.3258 ],
#                             [368.3836 ],
#                             [368.44846],
#                             [368.525  ],
#                             [368.60876],
#                             [368.69528],
#                             [368.7833 ],
#                             [368.87317],
#                             [368.9709 ],
#                             [369.07767],
#                             [369.19843],
#                             [369.33704],
#                             [369.48862],
#                             [369.64877],
#                             [369.81027],
#                             [369.96527],
#                             [370.10916],
#                             [370.23938],
#                             [370.35867],
#                             [370.47174],
#                             [370.57852],
#                             [370.68427],
#                             [370.79828],
#                             [370.91916],
#                             [371.0498 ],
#                             [371.193  ],
#                             [371.34772],
#                             [371.51114],
#                             [371.6792 ],
#                             [371.84726],
#                             [372.0122 ],
#                             [372.17432],
#                             [372.34   ],
#                             [372.5176 ],
#                             [372.71246],
#                             [372.92386],
#                             [373.1466 ],
#                             [373.37714],
#                             [373.61514],
#                             [373.85178],
#                             [374.08755],
#                             [374.3177 ],
#                             [374.53897],
#                             [374.75385],
#                             [374.96454],
#                             [375.17477],
#                             [375.38516],
#                             [375.59244],
#                             [375.79117],
#                             [375.97855],
#                             [376.15317],
#                             [376.31436],
#                             [376.46365],
#                             [376.60413],
#                             [376.73856],
#                             [376.8678 ],
#                             [376.9921 ],
#                             [377.10458],
#                             [377.2001 ],
#                             [377.28732],
#                             [377.381  ],
#                             [377.49252],
#                             [377.62646],
#                             [377.78644],
#                             [377.97067],
#                             [378.17416],
#                             [378.3916 ],
#                             [378.62006],
#                             [378.85217],
#                             [379.08435],
#                             [379.31143],
#                             [379.5342 ],
#                             [379.74918],
#                             [379.9553 ],
#                             [380.15512],
#                             [380.3576 ],
#                             [380.56192],
#                             [380.7646 ],
#                             [380.95944],
#                             [381.1409 ],
#                             [381.30893],
#                             [381.46335],
#                             [381.6037 ],
#                             [381.73367],
#                             [381.86118],
#                             [381.9915 ],
#                             [382.12378],
#                             [382.2595 ],
#                             [382.39853],
#                             [382.5447 ],
#                             [382.69855],
#                             [382.861  ],
#                             [383.0272 ],
#                             [383.1923 ],
#                             [383.35223],
#                             [383.5111 ],
#                             [383.67075],
#                             [383.8313 ],
#                             [383.99548],
#                             [384.15744],
#                             [384.31418],
#                             [384.4636 ],
#                             [384.60675],
#                             [384.74445],
#                             [384.88318],
#                             [385.03403],
#                             [385.20337],
#                             [385.37878],
#                             [385.55258],
#                             [385.72177],
#                             [385.88257],
#                             [386.03012],
#                             [386.16824],
#                             [386.30255],
#                             [386.43802]], dtype=float32),
#                DeviceArray([[[0.02223915]],
#
#                             [[0.01391804]],
#
#                             [[0.00985503]],
#
#                             [[0.00818536]],
#
#                             [[0.00765774]],
#
#                             [[0.00756268]],
#
#                             [[0.00756629]],
#
#                             [[0.00755066]],
#
#                             [[0.00749927]],
#
#                             [[0.00742948]],
#
#                             [[0.0073612 ]],
#
#                             [[0.00730658]],
#
#                             [[0.00726973]],
#
#                             [[0.00725162]],
#
#                             [[0.00724451]],
#
#                             [[0.00724244]],
#
#                             [[0.00724211]],
#
#                             [[0.00724213]],
#
#                             [[0.00724218]],
#
#                             [[0.00724219]],
#
#                             [[0.00724221]],
#
#                             [[0.00724218]],
#
#                             [[0.0072421 ]],
#
#                             [[0.00724199]],
#
#                             [[0.00724193]],
#
#                             [[0.00724193]],
#
#                             [[0.00724164]],
#
#                             [[0.00724118]],
#
#                             [[0.00724078]],
#
#                             [[0.00724055]],
#
#                             [[0.00724047]],
#
#                             [[0.00724046]],
#
#                             [[0.0072404 ]],
#
#                             [[0.00724023]],
#
#                             [[0.00723993]],
#
#                             [[0.00723961]],
#
#                             [[0.00723943]],
#
#                             [[0.00723943]],
#
#                             [[0.0072393 ]],
#
#                             [[0.00723903]],
#
#                             [[0.00723876]],
#
#                             [[0.00723859]],
#
#                             [[0.00723853]],
#
#                             [[0.00723854]],
#
#                             [[0.0072385 ]],
#
#                             [[0.00723835]],
#
#                             [[0.0072381 ]],
#
#                             [[0.00723784]],
#
#                             [[0.0072377 ]],
#
#                             [[0.00723771]],
#
#                             [[0.00723759]],
#
#                             [[0.00723736]],
#
#                             [[0.00723711]],
#
#                             [[0.00723697]],
#
#                             [[0.00723694]],
#
#                             [[0.00723694]],
#
#                             [[0.0072369 ]],
#
#                             [[0.00723678]],
#
#                             [[0.00723658]],
#
#                             [[0.00723636]],
#
#                             [[0.00723623]],
#
#                             [[0.00723622]],
#
#                             [[0.00723612]],
#
#                             [[0.00723593]],
#
#                             [[0.00723575]],
#
#                             [[0.00723563]],
#
#                             [[0.0072356 ]],
#
#                             [[0.0072356 ]],
#
#                             [[0.00723558]],
#
#                             [[0.00723547]],
#
#                             [[0.0072353 ]],
#
#                             [[0.00723512]],
#
#                             [[0.00723502]],
#
#                             [[0.00723499]],
#
#                             [[0.0072349 ]],
#
#                             [[0.00723475]],
#
#                             [[0.00723458]],
#
#                             [[0.00723448]],
#
#                             [[0.00723445]],
#
#                             [[0.00723446]],
#
#                             [[0.00723445]],
#
#                             [[0.00723437]],
#
#                             [[0.00723423]],
#
#                             [[0.00723408]],
#
#                             [[0.00723398]],
#
#                             [[0.00723395]],
#
#                             [[0.00723388]],
#
#                             [[0.00723374]],
#
#                             [[0.0072336 ]],
#
#                             [[0.00723351]],
#
#                             [[0.0072335 ]],
#
#                             [[0.00723351]],
#
#                             [[0.00723351]],
#
#                             [[0.00723344]],
#
#                             [[0.00723332]],
#
#                             [[0.00723318]],
#
#                             [[0.0072331 ]],
#
#                             [[0.00723307]],
#
#                             [[0.00723301]],
#
#                             [[0.00723288]],
#
#                             [[0.00723278]],
#
#                             [[0.00723271]],
#
#                             [[0.00723271]],
#
#                             [[0.00723272]],
#
#                             [[0.00723272]],
#
#                             [[0.00723267]],
#
#                             [[0.00723256]],
#
#                             [[0.00723244]],
#
#                             [[0.00723237]],
#
#                             [[0.00723233]],
#
#                             [[0.00723227]],
#
#                             [[0.00723217]],
#
#                             [[0.00723208]],
#
#                             [[0.00723203]],
#
#                             [[0.00723202]],
#
#                             [[0.00723205]],
#
#                             [[0.00723205]],
#
#                             [[0.00723201]],
#
#                             [[0.00723192]],
#
#                             [[0.00723183]],
#
#                             [[0.00723176]],
#
#                             [[0.00723173]],
#
#                             [[0.00723166]],
#
#                             [[0.00723158]],
#
#                             [[0.0072315 ]],
#
#                             [[0.00723145]],
#
#                             [[0.00723146]],
#
#                             [[0.00723149]],
#
#                             [[0.0072315 ]],
#
#                             [[0.00723146]],
#
#                             [[0.0072314 ]],
#
#                             [[0.00723131]],
#
#                             [[0.00723125]],
#
#                             [[0.0072312 ]],
#
#                             [[0.00723114]],
#
#                             [[0.00723107]],
#
#                             [[0.007231  ]],
#
#                             [[0.00723098]],
#
#                             [[0.00723098]],
#
#                             [[0.00723101]],
#
#                             [[0.00723103]],
#
#                             [[0.00723101]],
#
#                             [[0.00723095]],
#
#                             [[0.00723088]],
#
#                             [[0.00723081]],
#
#                             [[0.00723077]],
#
#                             [[0.00723071]],
#
#                             [[0.00723065]],
#
#                             [[0.0072306 ]],
#
#                             [[0.00723058]],
#
#                             [[0.00723059]],
#
#                             [[0.00723062]],
#
#                             [[0.00723064]],
#
#                             [[0.00723063]],
#
#                             [[0.00723058]],
#
#                             [[0.00723052]],
#
#                             [[0.00723046]],
#
#                             [[0.00723041]],
#
#                             [[0.00723035]],
#
#                             [[0.00723029]],
#
#                             [[0.00723027]],
#
#                             [[0.00723025]],
#
#                             [[0.00723025]],
#
#                             [[0.00723029]],
#
#                             [[0.0072303 ]],
#
#                             [[0.00723031]],
#
#                             [[0.00723028]],
#
#                             [[0.00723022]],
#
#                             [[0.00723016]],
#
#                             [[0.0072301 ]],
#
#                             [[0.00723005]],
#
#                             [[0.00723001]],
#
#                             [[0.00722998]],
#
#                             [[0.00722997]],
#
#                             [[0.00722999]],
#
#                             [[0.00723002]],
#
#                             [[0.00723005]],
#
#                             [[0.00723006]],
#
#                             [[0.00723004]],
#
#                             [[0.00722999]],
#
#                             [[0.00722993]],
#
#                             [[0.00722987]],
#
#                             [[0.00722981]],
#
#                             [[0.00722977]],
#
#                             [[0.00722975]],
#
#                             [[0.00722975]],
#
#                             [[0.00722977]],
#
#                             [[0.0072298 ]],
#
#                             [[0.00722984]],
#
#                             [[0.00722985]],
#
#                             [[0.00722983]],
#
#                             [[0.00722979]],
#
#                             [[0.00722973]],
#
#                             [[0.00722967]],
#
#                             [[0.00722961]],
#
#                             [[0.00722957]],
#
#                             [[0.00722955]],
#
#                             [[0.00722956]],
#
#                             [[0.00722959]],
#
#                             [[0.00722962]],
#
#                             [[0.00722967]],
#
#                             [[0.0072297 ]],
#
#                             [[0.00722969]],
#
#                             [[0.00722965]],
#
#                             [[0.00722959]],
#
#                             [[0.00722952]],
#
#                             [[0.00722946]],
#
#                             [[0.00722943]],
#
#                             [[0.00722941]],
#
#                             [[0.00722942]],
#
#                             [[0.00722945]],
#
#                             [[0.00722949]],
#
#                             [[0.00722954]],
#
#                             [[0.00722956]],
#
#                             [[0.00722957]],
#
#                             [[0.00722953]],
#
#                             [[0.00722947]],
#
#                             [[0.0072294 ]],
#
#                             [[0.00722934]],
#
#                             [[0.0072293 ]],
#
#                             [[0.00722931]],
#
#                             [[0.00722932]],
#
#                             [[0.00722934]],
#
#                             [[0.0072294 ]],
#
#                             [[0.00722945]],
#
#                             [[0.00722948]],
#
#                             [[0.00722949]],
#
#                             [[0.00722946]],
#
#                             [[0.0072294 ]],
#
#                             [[0.00722933]],
#
#                             [[0.00722926]],
#
#                             [[0.00722924]],
#
#                             [[0.00722924]],
#
#                             [[0.00722925]],
#
#                             [[0.00722928]],
#
#                             [[0.00722933]],
#
#                             [[0.00722938]],
#
#                             [[0.00722942]],
#
#                             [[0.00722943]],
#
#                             [[0.00722941]],
#
#                             [[0.00722934]],
#
#                             [[0.00722927]],
#
#                             [[0.0072292 ]],
#
#                             [[0.00722918]],
#
#                             [[0.00722918]],
#
#                             [[0.0072292 ]],
#
#                             [[0.00722923]],
#
#                             [[0.00722928]],
#
#                             [[0.00722934]],
#
#                             [[0.00722939]],
#
#                             [[0.0072294 ]],
#
#                             [[0.00722938]],
#
#                             [[0.00722932]],
#
#                             [[0.00722924]],
#
#                             [[0.00722918]],
#
#                             [[0.00722916]],
#
#                             [[0.00722917]],
#
#                             [[0.00722919]],
#
#                             [[0.00722922]],
#
#                             [[0.00722927]],
#
#                             [[0.00722934]],
#
#                             [[0.00722939]],
#
#                             [[0.00722941]],
#
#                             [[0.00722939]],
#
#                             [[0.00722933]],
#
#                             [[0.00722924]],
#
#                             [[0.00722918]],
#
#                             [[0.00722915]],
#
#                             [[0.00722917]],
#
#                             [[0.0072292 ]],
#
#                             [[0.00722923]],
#
#                             [[0.00722929]],
#
#                             [[0.00722936]],
#
#                             [[0.00722943]],
#
#                             [[0.00722946]],
#
#                             [[0.00722944]],
#
#                             [[0.00722937]],
#
#                             [[0.00722928]],
#
#                             [[0.00722921]],
#
#                             [[0.00722919]],
#
#                             [[0.00722921]],
#
#                             [[0.00722925]],
#
#                             [[0.00722928]],
#
#                             [[0.00722934]],
#
#                             [[0.00722942]],
#
#                             [[0.00722948]],
#
#                             [[0.00722951]],
#
#                             [[0.0072295 ]],
#
#                             [[0.00722943]],
#
#                             [[0.00722935]],
#
#                             [[0.00722927]],
#
#                             [[0.00722925]],
#
#                             [[0.00722927]],
#
#                             [[0.00722931]],
#
#                             [[0.00722934]],
#
#                             [[0.00722941]],
#
#                             [[0.00722949]],
#
#                             [[0.00722956]],
#
#                             [[0.00722961]],
#
#                             [[0.00722959]],
#
#                             [[0.00722952]],
#
#                             [[0.00722944]],
#
#                             [[0.00722937]],
#
#                             [[0.00722936]],
#
#                             [[0.00722938]],
#
#                             [[0.00722941]],
#
#                             [[0.00722945]],
#
#                             [[0.00722952]],
#
#                             [[0.00722961]],
#
#                             [[0.00722969]],
#
#                             [[0.00722974]],
#
#                             [[0.00722973]],
#
#                             [[0.00722966]],
#
#                             [[0.00722957]],
#
#                             [[0.00722951]],
#
#                             [[0.00722949]],
#
#                             [[0.00722952]],
#
#                             [[0.00722955]],
#
#                             [[0.00722959]],
#
#                             [[0.00722966]],
#
#                             [[0.00722976]],
#
#                             [[0.00722985]],
#
#                             [[0.00722991]],
#
#                             [[0.00722991]],
#
#                             [[0.00722983]],
#
#                             [[0.00722973]],
#
#                             [[0.00722967]],
#
#                             [[0.00722966]],
#
#                             [[0.0072297 ]],
#
#                             [[0.00722973]],
#
#                             [[0.00722978]],
#
#                             [[0.00722985]],
#
#                             [[0.00722995]],
#
#                             [[0.00723006]],
#
#                             [[0.00723012]],
#
#                             [[0.00723012]],
#
#                             [[0.00723005]],
#
#                             [[0.00722995]],
#
#                             [[0.00722989]],
#
#                             [[0.00722989]],
#
#                             [[0.00722991]],
#
#                             [[0.00722995]],
#
#                             [[0.00722999]],
#
#                             [[0.00723008]],
#
#                             [[0.00723019]],
#
#                             [[0.00723031]],
#
#                             [[0.00723038]],
#
#                             [[0.00723038]],
#
#                             [[0.00723031]],
#
#                             [[0.00723021]],
#
#                             [[0.00723015]],
#
#                             [[0.00723016]],
#
#                             [[0.0072302 ]],
#
#                             [[0.00723023]],
#
#                             [[0.00723027]],
#
#                             [[0.00723036]],
#
#                             [[0.00723049]],
#
#                             [[0.00723061]],
#
#                             [[0.0072307 ]],
#
#                             [[0.0072307 ]],
#
#                             [[0.00723062]],
#
#                             [[0.00723053]],
#
#                             [[0.00723047]],
#
#                             [[0.00723048]],
#
#                             [[0.00723053]],
#
#                             [[0.00723057]],
#
#                             [[0.00723062]],
#
#                             [[0.00723071]],
#
#                             [[0.00723084]],
#
#                             [[0.00723098]],
#
#                             [[0.00723108]],
#
#                             [[0.00723108]],
#
#                             [[0.00723099]],
#
#                             [[0.0072309 ]],
#
#                             [[0.00723085]],
#
#                             [[0.00723087]],
#
#                             [[0.00723093]],
#
#                             [[0.00723097]],
#
#                             [[0.00723101]],
#
#                             [[0.0072311 ]],
#
#                             [[0.00723124]],
#
#                             [[0.0072314 ]],
#
#                             [[0.00723152]],
#
#                             [[0.00723154]],
#
#                             [[0.00723146]],
#
#                             [[0.00723137]],
#
#                             [[0.00723133]],
#
#                             [[0.00723135]],
#
#                             [[0.00723141]],
#
#                             [[0.00723146]],
#
#                             [[0.00723149]],
#
#                             [[0.00723159]],
#
#                             [[0.00723175]],
#
#                             [[0.00723193]],
#
#                             [[0.00723206]],
#
#                             [[0.00723208]],
#
#                             [[0.007232  ]],
#
#                             [[0.00723192]],
#
#                             [[0.00723188]],
#
#                             [[0.00723192]],
#
#                             [[0.00723198]],
#
#                             [[0.00723203]],
#
#                             [[0.00723207]],
#
#                             [[0.00723218]],
#
#                             [[0.00723236]],
#
#                             [[0.00723256]],
#
#                             [[0.0072327 ]],
#
#                             [[0.00723273]],
#
#                             [[0.00723265]],
#
#                             [[0.00723258]],
#
#                             [[0.00723256]],
#
#                             [[0.00723261]],
#
#                             [[0.00723268]],
#
#                             [[0.00723273]],
#
#                             [[0.00723277]],
#
#                             [[0.00723288]],
#
#                             [[0.00723306]],
#
#                             [[0.00723329]],
#
#                             [[0.00723346]],
#
#                             [[0.0072335 ]],
#
#                             [[0.00723342]],
#
#                             [[0.00723334]],
#
#                             [[0.00723334]],
#
#                             [[0.00723341]],
#
#                             [[0.00723349]],
#
#                             [[0.00723355]],
#
#                             [[0.0072336 ]],
#
#                             [[0.00723371]],
#
#                             [[0.00723392]],
#
#                             [[0.00723416]],
#
#                             [[0.00723436]],
#
#                             [[0.00723441]],
#
#                             [[0.00723433]],
#
#                             [[0.00723428]],
#
#                             [[0.00723429]],
#
#                             [[0.00723437]],
#
#                             [[0.00723447]],
#
#                             [[0.00723452]],
#
#                             [[0.00723456]],
#
#                             [[0.00723468]],
#
#                             [[0.00723491]],
#
#                             [[0.00723519]],
#
#                             [[0.00723543]],
#
#                             [[0.0072355 ]],
#
#                             [[0.00723542]],
#
#                             [[0.00723537]],
# ...
#
#                             [[0.00632392]],
#
#                             [[0.00632362]],
#
#                             [[0.00632393]],
#
#                             [[0.00632412]],
#
#                             [[0.00632395]],
#
#                             [[0.0063237 ]],
#
#                             [[0.00632355]],
#
#                             [[0.00632355]],
#
#                             [[0.00632356]],
#
#                             [[0.00632371]],
#
#                             [[0.00632398]],
#
#                             [[0.0063241 ]],
#
#                             [[0.00632392]],
#
#                             [[0.00632369]],
#
#                             [[0.00632408]],
#
#                             [[0.00632441]],
#
#                             [[0.00632436]],
#
#                             [[0.00632417]],
#
#                             [[0.00632404]],
#
#                             [[0.00632405]],
#
#                             [[0.00632407]],
#
#                             [[0.00632425]],
#
#                             [[0.0063246 ]],
#
#                             [[0.00632485]],
#
#                             [[0.00632479]],
#
#                             [[0.00632461]],
#
#                             [[0.0063251 ]],
#
#                             [[0.00632558]],
#
#                             [[0.00632564]],
#
#                             [[0.0063255 ]],
#
#                             [[0.0063254 ]],
#
#                             [[0.00632541]],
#
#                             [[0.00632543]],
#
#                             [[0.00632564]],
#
#                             [[0.00632608]],
#
#                             [[0.00632647]],
#
#                             [[0.00632655]],
#
#                             [[0.00632641]],
#
#                             [[0.00632704]],
#
#                             [[0.00632768]],
#
#                             [[0.00632783]],
#
#                             [[0.00632775]],
#
#                             [[0.00632767]],
#
#                             [[0.00632769]],
#
#                             [[0.00632772]],
#
#                             [[0.00632795]],
#
#                             [[0.00632849]],
#
#                             [[0.00632905]],
#
#                             [[0.00632928]],
#
#                             [[0.00632917]],
#
#                             [[0.00633001]],
#
#                             [[0.00633081]],
#
#                             [[0.00633106]],
#
#                             [[0.00633103]],
#
#                             [[0.00633096]],
#
#                             [[0.00633099]],
#
#                             [[0.00633102]],
#
#                             [[0.00633128]],
#
#                             [[0.00633193]],
#
#                             [[0.00633269]],
#
#                             [[0.0063331 ]],
#
#                             [[0.00633301]],
#
#                             [[0.00633413]],
#
#                             [[0.00633514]],
#
#                             [[0.00633548]],
#
#                             [[0.00633548]],
#
#                             [[0.00633543]],
#
#                             [[0.00633546]],
#
#                             [[0.0063355 ]],
#
#                             [[0.00633579]],
#
#                             [[0.00633656]],
#
#                             [[0.00633756]],
#
#                             [[0.00633819]],
#
#                             [[0.00633812]],
#
#                             [[0.00633966]],
#
#                             [[0.00634089]],
#
#                             [[0.00634131]],
#
#                             [[0.00634135]],
#
#                             [[0.00634131]],
#
#                             [[0.00634135]],
#
#                             [[0.00634138]],
#
#                             [[0.00634171]],
#
#                             [[0.0063426 ]],
#
#                             [[0.00634388]],
#
#                             [[0.00634481]],
#
#                             [[0.00634476]],
#
#                             [[0.00634692]],
#
#                             [[0.00634841]],
#
#                             [[0.00634889]],
#
#                             [[0.00634895]],
#
#                             [[0.00634893]],
#
#                             [[0.00634898]],
#
#                             [[0.00634901]],
#
#                             [[0.00634937]],
#
#                             [[0.00635041]],
#
#                             [[0.00635202]],
#
#                             [[0.00635333]],
#
#                             [[0.00635331]],
#
#                             [[0.00635638]],
#
#                             [[0.00635816]],
#
#                             [[0.00635869]],
#
#                             [[0.00635877]],
#
#                             [[0.00635876]],
#
#                             [[0.00635882]],
#
#                             [[0.00635885]],
#
#                             [[0.00635924]],
#
#                             [[0.00636043]],
#
#                             [[0.00636243]],
#
#                             [[0.00636426]],
#
#                             [[0.00636427]],
#
#                             [[0.00636874]],
#
#                             [[0.00637082]],
#
#                             [[0.0063714 ]],
#
#                             [[0.00637149]],
#
#                             [[0.0063715 ]],
#
#                             [[0.00637156]],
#
#                             [[0.00637159]],
#
#                             [[0.006372  ]],
#
#                             [[0.00637334]],
#
#                             [[0.00637583]],
#
#                             [[0.00637836]],
#
#                             [[0.00637845]],
#
#                             [[0.00638503]],
#
#                             [[0.00638746]],
#
#                             [[0.00638803]],
#
#                             [[0.00638814]],
#
#                             [[0.00638816]],
#
#                             [[0.00638823]],
#
#                             [[0.00638825]],
#
#                             [[0.00638868]],
#
#                             [[0.0063902 ]],
#
#                             [[0.00639323]],
#
#                             [[0.00639672]],
#
#                             [[0.00639697]],
#
#                             [[0.00640686]],
#
#                             [[0.00640961]],
#
#                             [[0.00641017]],
#
#                             [[0.00641028]],
#
#                             [[0.00641031]],
#
#                             [[0.00641038]],
#
#                             [[0.0064104 ]],
#
#                             [[0.00641085]],
#
#                             [[0.00641253]],
#
#                             [[0.00641621]],
#
#                             [[0.00642102]],
#
#                             [[0.00642159]],
#
#                             [[0.00643674]],
#
#                             [[0.00643974]],
#
#                             [[0.00644026]],
#
#                             [[0.00644036]],
#
#                             [[0.0064404 ]],
#
#                             [[0.00644048]],
#
#                             [[0.00644049]],
#
#                             [[0.00644093]],
#
#                             [[0.00644278]],
#
#                             [[0.00644721]],
#
#                             [[0.00645383]],
#
#                             [[0.00645508]],
#
#                             [[0.00647867]],
#
#                             [[0.00648181]],
#
#                             [[0.00648224]],
#
#                             [[0.00648233]],
#
#                             [[0.00648238]],
#
#                             [[0.00648247]],
#
#                             [[0.00648246]],
#
#                             [[0.00648291]],
#
#                             [[0.00648491]],
#
#                             [[0.00649019]],
#
#                             [[0.00649924]],
#
#                             [[0.00650188]],
#
#                             [[0.00653934]],
#
#                             [[0.00654237]],
#
#                             [[0.00654268]],
#
#                             [[0.00654275]],
#
#                             [[0.00654281]],
#
#                             [[0.00654292]],
#
#                             [[0.0065429 ]],
#
#                             [[0.00654332]],
#
#                             [[0.00654545]],
#
#                             [[0.00655165]],
#
#                             [[0.006564  ]],
#
#                             [[0.00656947]],
#
#                             [[0.00662997]],
#
#                             [[0.00663252]],
#
#                             [[0.0066327 ]],
#
#                             [[0.00663274]],
#
#                             [[0.00663282]],
#
#                             [[0.00663295]],
#
#                             [[0.00663291]],
#
#                             [[0.0066333 ]],
#
#                             [[0.00663553]],
#
#                             [[0.00664271]],
#
#                             [[0.00665941]],
#
#                             [[0.00667063]],
#
#                             [[0.00676997]],
#
#                             [[0.00677163]],
#
#                             [[0.00677169]],
#
#                             [[0.00677169]],
#
#                             [[0.0067718 ]],
#
#                             [[0.00677195]],
#
#                             [[0.00677191]],
#
#                             [[0.00677225]],
#
#                             [[0.00677453]],
#
#                             [[0.00678271]],
#
#                             [[0.00680503]],
#
#                             [[0.00682779]],
#
#                             [[0.00699356]],
#
#                             [[0.00699409]],
#
#                             [[0.00699407]],
#
#                             [[0.00699405]],
#
#                             [[0.00699417]],
#
#                             [[0.00699437]],
#
#                             [[0.00699432]],
#
#                             [[0.00699459]],
#
#                             [[0.00699687]],
#
#                             [[0.00700598]],
#
#                             [[0.00703534]],
#
#                             [[0.00708122]],
#
#                             [[0.00736203]],
#
#                             [[0.00736212]],
#
#                             [[0.00736213]],
#
#                             [[0.00736207]],
#
#                             [[0.00736222]],
#
#                             [[0.00736248]],
#
#                             [[0.00736242]],
#
#                             [[0.00736261]],
#
#                             [[0.00736483]],
#
#                             [[0.00737471]],
#
#                             [[0.00741242]],
#
#                             [[0.00750445]],
#
#                             [[0.00798691]],
#
#                             [[0.00799007]],
#
#                             [[0.00799024]],
#
#                             [[0.00799016]],
#
#                             [[0.00799033]],
#
#                             [[0.00799067]],
#
#                             [[0.00799062]],
#
#                             [[0.00799071]],
#
#                             [[0.00799281]],
#
#                             [[0.00800316]],
#
#                             [[0.00804999]],
#
#                             [[0.00823392]],
#
#                             [[0.00907389]],
#
#                             [[0.00909088]],
#
#                             [[0.00909132]],
#
#                             [[0.00909121]],
#
#                             [[0.00909142]],
#
#                             [[0.00909185]],
#
#                             [[0.00909183]],
#
#                             [[0.00909183]],
#
#                             [[0.00909371]],
#
#                             [[0.00910413]],
#
#                             [[0.00915944]],
#
#                             [[0.00952611]],
#
#                             [[0.01100652]],
#
#                             [[0.01106547]],
#
#                             [[0.01106615]],
#
#                             [[0.01106603]],
#
#                             [[0.0110663 ]],
#
#                             [[0.01106685]],
#
#                             [[0.01106688]],
#
#                             [[0.01106679]],
#
#                             [[0.01106838]],
#
#                             [[0.01107829]],
#
#                             [[0.01113869]],
#
#                             [[0.01186819]]], dtype=float32)))])

# %%
param_dummy_sample
# Out:
# {'local_linear_trend': {'cov_level': DeviceArray([[[0.00013296]]], dtype=float32),
#   'cov_slope': DeviceArray([[[0.00093122]]], dtype=float32)},
#  'obs_model': {'cov': DeviceArray([[[0.05486585]]], dtype=float32)},
#  'seasonal_dummy': {'drift_cov': DeviceArray([[[0.00180501]]], dtype=float32)}}

# %%
# Plot the forecast
plot_forecast(model_dummy_season, param_dummy_sample, observed_time_series)
plot_decompose(model_dummy_season, param_dummy_sample)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb Cell 13 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> # Plot the forecast
# ----> <a href='vscode-notebook-cell:/home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> plot_forecast(model_dummy_season, param_dummy_sample, observed_time_series)
#       <a href='vscode-notebook-cell:/home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> plot_decompose(model_dummy_season, param_dummy_sample)
#
# /home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb Cell 13 in plot_forecast(model, parameter_samples, observed_time_series)
#      <a href='vscode-notebook-cell:/home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb#X22sZmlsZQ%3D%3D?line=46'>47</a> def plot_forecast(model, parameter_samples, observed_time_series):
#      <a href='vscode-notebook-cell:/home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb#X22sZmlsZQ%3D%3D?line=47'>48</a>     # Forecast
# ---> <a href='vscode-notebook-cell:/home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb#X22sZmlsZQ%3D%3D?line=48'>49</a>     forecasts = model.forecast(jr.PRNGKey(0), observed_time_series, parameter_samples, num_forecast_steps)
#      <a href='vscode-notebook-cell:/home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb#X22sZmlsZQ%3D%3D?line=49'>50</a>     forecast_means = jnp.squeeze(forecasts['means'].mean(axis=0))
#      <a href='vscode-notebook-cell:/home/xinglong/git_local/dynamax/dynamax/structural_time_series/models/sts_co2_demo.ipynb#X22sZmlsZQ%3D%3D?line=50'>51</a>     forecast_scales = jnp.squeeze(jnp.sqrt(forecasts['covariances']).mean(axis=0))
#
# File ~/git_local/dynamax/dynamax/structural_time_series/models/sts_model.py:334, in StructuralTimeSeries.forecast(self, key, observed_time_series, sts_params, num_forecast_steps, past_inputs, forecast_inputs)
#     331     return [means, covs, ts]
#     333 if self.obs_family == 'Gaussian':
# --> 334     forecasts = vmap(single_forecast_gaussian)(sts_params)
#     335 elif self.obs_family == 'Poisson':
#     336     forecasts = vmap(single_forecast_poisson)(sts_params)
#
#     [... skipping hidden 20 frame]
#
# File ~/git_local/dynamax/dynamax/structural_time_series/models/sts_model.py:303, in StructuralTimeSeries.forecast.<locals>.single_forecast_gaussian(sts_param)
#     301 @jit
#     302 def single_forecast_gaussian(sts_param):
# --> 303     sts_ssm = GaussianSSM(self.transition_matrices,
#     304                           self.observation_matrices,
#     305                           self.initial_state_priors,
#     306                           sts_param['dynamics_covariances'],
#     307                           self.transition_covariance_priors,
#     308                           sts_param['emission_covariance'],
#     309                           self.observation_covariance_prior,
#     310                           self.cov_spars_matrices,
#     311                           sts_param['regression_weights'],
#     312                           self.observation_regression_weights_prior
#     313                           )
#     314     means, covs, ts = sts_ssm.forecast(key, observed_time_series, num_forecast_steps,
#     315                                        past_inputs, forecast_inputs)
#     316     return [means, covs, ts]
#
# AttributeError: 'StructuralTimeSeries' object has no attribute 'transition_matrices'

# %%
# Fit the model with trigonometric seasonal component
opt_param_trig, _losses = model_trig_season.fit_mle(observed_time_series, key=key)
param_trig_sample = tree_map(lambda x: jnp.array([x]), opt_param_trig)

# Plot the forecast
plot_forecast(model_trig_season, param_trig_sample, observed_time_series)
plot_decompose(model_trig_season, param_trig_sample)

# %% [markdown]
# ### Fitting with HMC

# %%
param_dummy_samples = model_dummy_season.fit_hmc(key, sample_size, observed_time_series,
                                                 inputs=None, warmup_steps=200, num_integration_steps=15)

# Plot the forecast
plot_forecast(model_dummy_season, param_dummy_samples, observed_time_series)
plot_decompose(model_dummy_season, param_dummy_samples)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
param_trig_samples = model_trig_season.fit_hmc(key, sample_size, observed_time_series,
                                              inputs=None, warmup_steps=200, num_integration_steps=15)

# Plot the forecast
plot_forecast(model_trig_season, param_trig_samples, observed_time_series)
plot_decompose(model_trig_season, param_trig_samples)
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
